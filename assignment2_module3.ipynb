# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
data = pd.read_csv("D:\Assignment2\Question_1_output_file.csv")#input as dataframe
Dframe=pd.DataFrame(data)
Dframe['Continent']=Dframe['Continent'].replace(np.nan,'NA')#replace nan values with NA  
Newframe=Dframe.groupby(['Continent'],sort=False)['1979','1980','1981','1982','1983','1984','1985','1986','1987','1988','1989','1990','1991','1992','1993','1994','1995','1996','1997','1998','1999','2000','2001','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011'].mean()
Newframe2=Newframe.transpose()#Transpose to access years in X-axis
a=plt.figure(figsize=(20,4))#Decides the graph size
plt.title('No continent')#to get the title of graph
all_plots1=plt.plot(Newframe2.index,Newframe3['No continent'],color='B')
b=plt.figure(figsize=(20,4))
plt.title('Asia')
all_plots2=plt.plot(Newframe2.index,Newframe3['AS'],color='B')
c=plt.figure(figsize=(20,4))
plt.title('Europe')
all_plots3=plt.plot(Newframe2.index,Newframe3['EU'],color='B')
d=plt.figure(figsize=(20,4))
plt.title('Africa')
all_plots4=plt.plot(Newframe2.index,Newframe3['AF'],color='B')
e=plt.figure(figsize=(20,4))
plt.title('Oceania')
all_plots5=plt.plot(Newframe2.index,Newframe3['OC'],color='B')
f=plt.figure(figsize=(20,4))
plt.title('North America')
all_plots6=plt.plot(Newframe2.index,Newframe3['NA'],color='B')
g=plt.figure(figsize=(20,4))
plt.title('South America')
all_plots7=plt.plot(Newframe2.index,Newframe3['SA'],color='B')
h=plt.figure(figsize=(20,4))
plt.title('Antarctica')
all_plots8=plt.plot(Newframe2.index,Newframe3['AN'],color='B')
m=plt.figure(figsize=(20,8))
plt.title('All continents')
all_plots8=plt.plot(Newframe2.index,Newframe3['AS'],label='Asia',color='R')
all_plots8=plt.plot(Newframe2.index,Newframe3['EU'],label='Europe',color='Y')
all_plots8=plt.plot(Newframe2.index,Newframe3['AF'],label='Africa',color='c')
all_plots8=plt.plot(Newframe2.index,Newframe3['OC'],label='Oceania',color='m')
all_plots8=plt.plot(Newframe2.index,Newframe3['NA'],label='North America',color='k')
all_plots8=plt.plot(Newframe2.index,Newframe3['SA'],label='South America',color='g')
all_plots8=plt.plot(Newframe2.index,Newframe3['AN'],label='Antarctica',color='b')
plt.legend()
